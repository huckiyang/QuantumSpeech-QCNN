# %% [markdown]
# # **[Decentralizing Feature Extraction with Quantum Convolutional Neural Network for Automatic Speech Recognition](https://arxiv.org/abs/2010.13309)**  IEEE ICASSP 2021
#
# Author: C.-H. Huck Yang*
#
# Georgia Tech*, Brookhaven National Laboratory, IBM Research, University of Enna
#
# We would like to appreciate Xanadu AI for providing the PennyLane and IBM research for providing qiskit and quantum hardware to the community. There is no conflict of interest. We got the inspiration from the [post](https://pennylane.ai/qml/demos/tutorial_quanvolution.html) as Xanadu's demo (Author: Andrea Mari) and further apply some neural saliency analysis.

# %%
# !git clone https://github.com/huckiyang/speech_quantum_dl
# %cd speech_quantum_dl
# Out:
# Cloning into 'speech_quantum_dl'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 451 (delta 56), reused 18 (delta 6), pack-reused 358
# Receiving objects: 100% (451/451), 877.83 MiB | 43.68 MiB/s, done.
# Resolving deltas: 100% (254/254), done.
# Checking out files: 100% (35/35), done.
# /content/speech_quantum_dl

# %% [markdown]
# # **Command Classification Training with CE Loss**

# %%
# !pip install pennylane
# !pip install qiskit
# !python main_qsr.py
# Out:
# 2021-02-27 04:28:36.853684: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-27 04:28:39.799356: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-27 04:28:39.801744: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-27 04:28:39.807732: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-02-27 04:28:39.807782: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: 9dca2ed03423
# 2021-02-27 04:28:39.807802: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: 9dca2ed03423
# 2021-02-27 04:28:39.807929: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# 2021-02-27 04:28:39.807973: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# 2021-02-27 04:28:39.807992: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 460.32.3
# 2021-02-27 04:28:39.808336: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 30, 63, 4)]  0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 30, 63, 4)    16          input_2[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 63, 30, 4)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 63, 30, 16)   336         permute[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 63, 30, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 63, 30, 32)   2592        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 63, 30, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 63, 30, 16)   2576        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 63, 30, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 63, 30, 32)   0           batch_normalization_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 63, 30, 1)    161         concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 63, 30, 1)    4           conv2d_3[0][0]
# __________________________________________________________________________________________________
# squeeze_last_dim (Lambda)       (None, 63, 30)       0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 63, 128)      48640       squeeze_last_dim[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 63, 128)      98816       bidirectional[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 128)          0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          16512       lambda[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 63)           0           dense[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# attSoftmax (Softmax)            (None, 63)           0           dot[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 128)          0           attSoftmax[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dot_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dense_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 10)           330         dense_2[0][0]
# ==================================================================================================
# Total params: 180,575
# Trainable params: 180,437
# Non-trainable params: 138
# __________________________________________________________________________________________________
# 2021-02-27 04:28:40.851526: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-27 04:28:40.851954: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 
I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10

# %%
from IPython.display import Image
Image('images/cam_sp_0.png')

# %% [markdown]
# # **Part 2. CTC model with Word Error Rate(WER) evaluation**

# %%
# %cd data_quantum/asr_set
# !bash unzip.sh
# %cd ../..
# Out:
# /content/speech_quantum_dl/data_quantum/asr_set
# Archive:  tmp1.zip
# warning [tmp1.zip]:  zipfile claims to be last disk of a multi-part archive;
#   attempting to process anyway, assuming all parts have been concatenated
#   together in order.  Expect "errors" and warnings...true multi-part support
#   doesn't exist yet (coming soon).
# warning [tmp1.zip]:  292552704 extra bytes at beginning or within zipfile
#   (attempting to process anyway)
# file #1:  bad zipfile offset (local header sig):  292552708
#   (attempting to re-compensate)
#   inflating: asr_q_tr.npy
# Archive:  tmp2.zip
# warning [tmp2.zip]:  zipfile claims to be last disk of a multi-part archive;
#   attempting to process anyway, assuming all parts have been concatenated
#   together in order.  Expect "errors" and warnings...true multi-part support
#   doesn't exist yet (coming soon).
# warning [tmp2.zip]:  97517568 extra bytes at beginning or within zipfile
#   (attempting to process anyway)
# file #1:  bad zipfile offset (local header sig):  97517572
#   (attempting to re-compensate)
#   inflating: asr_x_tr.npy
# Archive:  asr_q_val.zip
#   inflating: asr_q_val.npy
# /content/speech_quantum_dl

# %%
# !python qsr_ctc_wer.py
# Out:
# 2021-02-27 04:24:56.389528: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-27 04:24:57.962611: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-27 04:24:57.963568: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-27 04:24:57.993156: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 04:24:57.993753: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-27 04:24:57.993792: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-27 04:24:57.997561: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-27 04:24:57.997629: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-27 04:24:57.999217: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-27 04:24:57.999586: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-27 04:24:58.007537: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-27 04:24:58.011341: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-27 04:24:58.016669: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-27 04:24:58.016789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 04:24:58.017351: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 04:24:58.017871: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-27 04:24:58.018295: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-27 04:24:58.018438: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 04:24:58.019022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-27 04:24:58.019054: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-27 04:24:58.019086: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-27 04:24:58.019111: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-27 04:24:58.019133: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-27 04:24:58.019154: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-27 04:24:58.019179: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-27 04:24:58.019200: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-27 04:24:58.019222: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-27 04:24:58.019291: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 04:24:58.019875: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 04:24:58.020395: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-27 04:24:58.020439: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-27 04:24:58.528203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-02-27 04:24:58.528268: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-02-27 04:24:58.528286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-02-27 04:24:58.528498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 04:24:58.529080: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 04:24:58.529677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 04:24:58.530189: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-02-27 04:24:58.530241: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13994 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# Load Data
# -- Validation Size:  (1705,) (1705, 60, 126, 1) (1705, 30, 63, 4)
# -- Training Size:  (6818,) (6818, 60, 126, 1) (6818, 30, 63, 4)
# Model: "asr_model_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# speech (InputLayer)             [(None, 30, 63, 4)]  0
# __________________________________________________________________________________________________
# permute (Permute)               (None, 63, 30, 4)    0           speech[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 63, 30, 16)   336         permute[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 63, 30, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 63, 30, 32)   2592        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 63, 30, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 63, 30, 16)   2576        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 63, 30, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 63, 30, 32)   0           batch_normalization[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 63, 30, 1)    161         concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 63, 30, 1)    4           conv2d_3[0][0]
# __________________________________________________________________________________________________
# squeeze_last_dim (Lambda)       (None, 63, 30)       0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 63, 128)      48640       squeeze_last_dim[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 63, 128)      98816       bidirectional[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 63, 64)       8256        bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense11 (Dense)                 (None, 63, 32)       2080        dense1[0][0]
# __________________________________________________________________________________________________
# label (InputLayer)              [(None, None)]       0
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 63, 26)       858         dense11[0][0]
# __________________________________________________________________________________________________
# ctc_loss (CTCLayer)             (None, 63, 26)       0           label[0][0]
#                                                                  dense2[0][0]
# ==================================================================================================
# Total params: 164,575
# Trainable params: 164,445
# Non-trainable params: 130
# __________________________________________________________________________________________________
# === Making CTC input dataset ...
# 2021-02-27 04:25:00.275740: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 412352640 exceeds 10% of free system memory.
# 2021-02-27 04:25:00.348914: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-27 04:25:00.350083: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# 2021-02-27 04:25:00.372242: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 412352640 exceeds 10% of free system memory.
# Epoch 1/50
# 2021-02-27 04:25:05.006954: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-27 04:25:05.266650: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 107/107 [==============================] - 14s 70ms/step - loss: 50.5798 - val_loss: 14.1002
# 2021-02-27 04:25:14.040998: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 412352640 exceeds 10% of free system memory.
# Epoch 2/50
# 107/107 [==============================] - 6s 54ms/step - loss: 3.3990 - val_loss: 15.1157
# 2021-02-27 04:25:20.189724: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 412352640 exceeds 10% of free system memory.
# Epoch 3/50
# 107/107 [==============================] - 6s 52ms/step - loss: 2.5789 - val_loss: 15.8177
# 2021-02-27 04:25:25.962587: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 412352640 exceeds 10% of free system memory.
# Epoch 4/50
# 107/107 [==============================] - 6s 55ms/step - loss: 2.4630 - val_loss: 8.2774
# Epoch 5/50
# 107/107 [==============================] - 5s 50ms/step - loss: 2.4469 - val_loss: 2.6136
# Epoch 6/50
# 107/107 [==============================] - 5s 50ms/step - loss: 2.3808 - val_loss: 2.2171
# Epoch 7/50
# 107/107 [==============================] - 6s 51ms/step - loss: 2.1816 - val_loss: 10.2729
# Epoch 8/50
# 107/107 [==============================] - 6s 55ms/step - loss: 1.8075 - val_loss: 55.7436
# Epoch 9/50
# 107/107 [==============================] - 6s 54ms/step - loss: 1.5019 - val_loss: 2.1982
# Epoch 10/50
# 107/107 [==============================] - 5s 50ms/step - loss: 1.3127 - val_loss: 1.2504
# Epoch 11/50
# 107/107 [==============================] - 5s 51ms/step - loss: 1.1271 - val_loss: 2.8286
# Epoch 12/50
# 107/107 [==============================] - 6s 52ms/step - loss: 0.9365 - val_loss: 7.3718
# Epoch 13/50
# 107/107 [==============================] - 6s 52ms/step - loss: 0.7796 - val_loss: 1.8483
# Epoch 14/50
# 107/107 [==============================] - 5s 51ms/step - loss: 0.7003 - val_loss: 1.7339
# Epoch 15/50
# 107/107 [==============================] - 6s 58ms/step - loss: 0.5937 - val_loss: 2.5110
# Epoch 16/50
# 107/107 [==============================] - 6s 59ms/step - loss: 0.5085 - val_loss: 1.2253
# Epoch 17/50
# 107/107 [==============================] - 6s 55ms/step - loss: 0.4097 - val_loss: 0.6028
# Epoch 18/50
# 107/107 [==============================] - 6s 54ms/step - loss: 0.3529 - val_loss: 2.4535
# Epoch 19/50
# 107/107 [==============================] - 5s 50ms/step - loss: 0.3047 - val_loss: 2.5728
# Epoch 20/50
# 107/107 [==============================] - 6s 55ms/step - loss: 0.2878 - val_loss: 0.4923
# Epoch 21/50
# 107/107 [==============================] - 6s 51ms/step - loss: 0.2654 - val_loss: 1.9387
# Epoch 22/50
# 107/107 [==============================] - 6s 52ms/step - loss: 0.2760 - val_loss: 0.7980
# Epoch 23/50
# 107/107 [==============================] - 6s 52ms/step - loss: 0.2364 - val_loss: 0.6384
# Epoch 24/50
# 107/107 [==============================] - 5s 50ms/step - loss: 0.2069 - val_loss: 2.1406
# Epoch 25/50
# 107/107 [==============================] - 6s 52ms/step - loss: 0.2217 - val_loss: 1.5287
# Epoch 26/50
# 107/107 [==============================] - 6s 52ms/step - loss: 0.1885 - val_loss: 2.9544
# Epoch 27/50
# 107/107 [==============================] - 6s 53ms/step - loss: 0.1660 - val_loss: 3.5474
# Epoch 28/50
# 107/107 [==============================] - 6s 55ms/step - loss: 0.1452 - val_loss: 0.6063
# Epoch 29/50
# 107/107 [==============================] - 6s 55ms/step - loss: 0.1727 - val_loss: 1.8884
# Epoch 30/50
# 107/107 [==============================] - 5s 50ms/step - loss: 0.1420 - val_loss: 0.5419
# ['on', 'go', 'go', 'go', 'on', 'go', 'no', 'no', 'on', 'no', 'go', 'on', 'up', 'no', 'go', 'no', 'up', 'on', 'on', 'go', 'up', 'no', 'on', 'on', 'no', 'on', 'no', 'go', 'up', 'on', 'go', 'go', 'go', 'no', 'no', 'no', 'go', 'no', 'no', 'go', 'go', 'no', 'on', 'on', 'go', 'o[UNK]', 'up', 'up', 'up', 'go', 'go', 'go', 'no', 'no', 'no', 'on', 'go', 'on', 'go', 'go', 'on', 'up', 'on', 'up', 'up', 'on', 'on', 'go', 'no', 'no', 'on', 'on', 'on', 'up', 'go', 'go', 'on', 'on', 'no', 'on', 'on', 'no', 'up', 'up', 'up', 'no', 'go', 'on', 'go', 'no', 'no', 'up', 'go', 'no', 'up', 'go', 'up', 'on', 'up', 'no', 'go', 'no', 'up', 'go', 'on', 'on', 'on', 'go', 'on', 'go', 'go', 'no', 'on', 'go', 'o[UNK]', 'no', 'go', 'go', 'o[UNK]', 'o[UNK]', 'go', 'go', 'up', 'go', 'go', 'go', 'up', 'no', 'up', 'go', 'no', 'no', 'up', 'on', 'up', 'on', 'up', 'on', 'go', 'go', 'on', 'on', 'on', 'on', 'on', 'on', 'up', 'go', 'go', 'on', 'on', 'up', 'no', 'up', 'on', 'on', 'on', 'go', 'no', 'on', 'no', 'on', 'up', 'on', 'go', 'on', 'up', 'up', 'go', 'up', 'up', 'on', 'o[UNK]', 'no', 'up', 'no', 'on', 'no', 'on', 'go', 'no', 'up', 'up', 'up', 'no', 'on', 'up', 'on', 'on', 'up', 'on', 'go']
# === WER: 10.416666666666666  %
